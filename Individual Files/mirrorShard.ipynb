# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator, PercentFormatter)
import numpy as np
pd.set_option('display.max_rows', 50)

# %%
kalandra = pd.read_csv("../Currency/Kalandra.currency.csv", sep = ";")
sentinel = pd.read_csv("../Currency/Sentinel.currency.csv", sep = ";")
archnemesis = pd.read_csv("../Currency/Archnemesis.currency.csv", sep = ";")
scourge = pd.read_csv("../Currency/Scourge.currency.csv", sep = ";")
expedition = pd.read_csv("../Currency/Expedition.currency.csv", sep = ";")
ultimatum = pd.read_csv("../Currency/Ultimatum.currency.csv", sep = ";")
ritual = pd.read_csv("../Currency/Ritual.currency.csv", sep = ";")

# %%
kalandra.head()
kalandra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37982 entries, 0 to 37981
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   League      37982 non-null  object
#  1   Date        37982 non-null  object
#  2   Get         37982 non-null  object
#  3   Pay         37982 non-null  object
#  4   Value       37982 non-null  float64
#  5   Confidence  37982 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# kalandra_unique_name = kalandra['Get'].unique()
# kalandra_unique_name

# %% [markdown]
# Mirror Shard

# %% [markdown]
# kalandra.loc[kalandra['Get']=='Mirror Shard']
# sentinel.loc[sentinel['Get']=='Mirror Shard']

# %%
kalandra.loc[ kalandra.Value >250000]
# Out:
#          League        Date                 Get        Pay        Value  \
# 36100  Kalandra  2022-09-02  Mirror of Kalandra  Chaos Orb  280000.0000
# 36101  Kalandra  2022-09-03  Mirror of Kalandra  Chaos Orb  280000.0000
# 36102  Kalandra  2022-09-04  Mirror of Kalandra  Chaos Orb  280000.0000
# 36103  Kalandra  2022-09-05  Mirror of Kalandra  Chaos Orb  279801.5873
# 36105  Kalandra  2022-09-07  Mirror of Kalandra  Chaos Orb  280000.0000
#
#       Confidence
# 36100        Low
# 36101        Low
# 36102        Low
# 36103        Low
# 36105        Low

# %%
kalandra['Date']
# Out:
# 0        2022-08-19
# 1        2022-08-20
# 2        2022-08-21
# 3        2022-08-22
# 4        2022-08-23
#             ...
# 37977    2022-12-02
# 37978    2022-12-03
# 37979    2022-12-04
# 37980    2022-12-05
# 37981    2022-12-06
# Name: Date, Length: 37982, dtype: object

# %%
kalandra_mirrorShard = kalandra.loc[kalandra['Get']=='Mirror Shard']
sentinel_mirrorShard = sentinel.loc[sentinel['Get']=='Mirror Shard']
archnemesis_mirrorShard = archnemesis.loc[archnemesis['Get']=='Mirror Shard']
scourge_mirrorShard = scourge.loc[scourge['Get']=='Mirror Shard']

expedition_mirrorShard = expedition.loc[expedition['Get']=='Mirror Shard']
ultimatum_mirrorShard = ultimatum.loc[ultimatum['Get']=='Mirror Shard']
ritual_mirrorShard = ritual.loc[ritual['Get']=='Mirror Shard']


kalandra_mirrorShard
# Out:
#          League        Date           Get        Pay       Value Confidence
# 12068  Kalandra  2022-08-20  Mirror Shard  Chaos Orb   550.00000        Low
# 12069  Kalandra  2022-08-22  Mirror Shard  Chaos Orb    65.57727        Low
# 12070  Kalandra  2022-08-23  Mirror Shard  Chaos Orb   938.23530     Medium
# 12071  Kalandra  2022-08-24  Mirror Shard  Chaos Orb   908.56842        Low
# 12072  Kalandra  2022-08-25  Mirror Shard  Chaos Orb   929.60000        Low
# ...         ...         ...           ...        ...         ...        ...
# 12171  Kalandra  2022-12-02  Mirror Shard  Chaos Orb  5969.24392       High
# 12172  Kalandra  2022-12-03  Mirror Shard  Chaos Orb  6013.10844       High
# 12173  Kalandra  2022-12-04  Mirror Shard  Chaos Orb  6048.69118       High
# 12174  Kalandra  2022-12-05  Mirror Shard  Chaos Orb  5943.54545       High
# 12175  Kalandra  2022-12-06  Mirror Shard  Chaos Orb  6258.27259       High
#
# [108 rows x 6 columns]

# %%
archnemesis_mirrorShard.head(20)
# Out:
#            League        Date           Get        Pay       Value Confidence
# 6858  Archnemesis  2022-02-05  Mirror Shard  Chaos Orb   865.92158     Medium
# 6859  Archnemesis  2022-02-06  Mirror Shard  Chaos Orb   583.77714       High
# 6860  Archnemesis  2022-02-07  Mirror Shard  Chaos Orb   678.21764       High
# 6861  Archnemesis  2022-02-08  Mirror Shard  Chaos Orb   623.19970       High
# 6862  Archnemesis  2022-02-09  Mirror Shard  Chaos Orb   649.05804       High
# 6863  Archnemesis  2022-02-10  Mirror Shard  Chaos Orb   856.00000       High
# 6864  Archnemesis  2022-02-11  Mirror Shard  Chaos Orb   936.00000       High
# 6865  Archnemesis  2022-02-12  Mirror Shard  Chaos Orb   911.41738       High
# 6866  Archnemesis  2022-02-13  Mirror Shard  Chaos Orb   873.96479       High
# 6867  Archnemesis  2022-02-14  Mirror Shard  Chaos Orb  1177.90601       High
# 6868  Archnemesis  2022-02-15  Mirror Shard  Chaos Orb  1420.78278       High
# ...

# %%
scourge_mirrorShard
# Out:
#         League        Date           Get        Pay       Value Confidence
# 19107  Scourge  2021-10-24  Mirror Shard  Chaos Orb  1072.23322        Low
# 19108  Scourge  2021-10-25  Mirror Shard  Chaos Orb   624.00000       High
# 19109  Scourge  2021-10-26  Mirror Shard  Chaos Orb   521.41818       High
# 19110  Scourge  2021-10-27  Mirror Shard  Chaos Orb   499.74249       High
# 19111  Scourge  2021-10-28  Mirror Shard  Chaos Orb   530.73608       High
# ...        ...         ...           ...        ...         ...        ...
# 19203  Scourge  2022-01-28  Mirror Shard  Chaos Orb  4545.17948       High
# 19204  Scourge  2022-01-29  Mirror Shard  Chaos Orb  4683.54872       High
# 19205  Scourge  2022-01-30  Mirror Shard  Chaos Orb  4572.00000       High
# 19206  Scourge  2022-01-31  Mirror Shard  Chaos Orb  4513.86823       High
# 19207  Scourge  2022-02-01  Mirror Shard  Chaos Orb  4680.00000       High
#
# [101 rows x 6 columns]

# %% [markdown]
# KALANDRA

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard for kalandra', fontsize=15,fontweight='bold')
ax.plot(kalandra_mirrorShard['Date'],kalandra_mirrorShard['Value'])
fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\2887157907.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# SENTINEL

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard for sentinel', fontsize=15,fontweight='bold')
ax.plot(sentinel_mirrorShard['Date'],sentinel_mirrorShard['Value'])
fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\3359553903.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ARCHNEMESIS

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard for archnemesis', fontsize=15,fontweight='bold')
ax.plot(archnemesis_mirrorShard['Date'],archnemesis_mirrorShard['Value'])
fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\3092478908.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# SCOURGE

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard for scourge', fontsize=15,fontweight='bold')
ax.plot(scourge_mirrorShard['Date'],scourge_mirrorShard['Value'])
fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\3112527106.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
kalandra_newID = kalandra_mirrorShard.copy()
kalandra_newID = kalandra_newID[kalandra_newID.Value > 66]
kalandra_newID.insert(0, 'Days', range(1, 1+len(kalandra_newID['Date'])))
kalandra_newID = kalandra_newID.reset_index()
kalandra_newID = kalandra_newID.drop(columns=['index'])

# %%
sentinel_newID = sentinel_mirrorShard.copy()
sentinel_newID.insert(0, 'Days', range(1, 1+len(sentinel_newID['Date'])))
sentinel_newID = sentinel_newID.reset_index()
sentinel_newID = sentinel_newID.drop(columns=['index'])

# %%
archnemesis_newID = archnemesis_mirrorShard.copy()
archnemesis_newID.insert(0, 'Days', range(1, 1+len(archnemesis_newID['Date'])))
archnemesis_newID = archnemesis_newID.reset_index()
archnemesis_newID = archnemesis_newID.drop(columns=['index'])

# %%
scourge_newID = scourge_mirrorShard.copy()
scourge_newID.insert(0, 'Days', range(1, 1+len(scourge_newID['Date'])))
scourge_newID = scourge_newID.reset_index()
scourge_newID = scourge_newID.drop(columns=['index'])

# %%
expedition_newID = expedition_mirrorShard.copy()
expedition_newID.insert(0, 'Days', range(1, 1+len(expedition_newID['Date'])))
expedition_newID = expedition_newID.reset_index()
expedition_newID = expedition_newID.drop(columns=['index'])

# %%
ultimatum_newID = ultimatum_mirrorShard.copy()
ultimatum_newID.insert(0, 'Days', range(1, 1+len(ultimatum_newID['Date'])))
ultimatum_newID = ultimatum_newID.reset_index()
ultimatum_newID = ultimatum_newID.drop(columns=['index'])

# %%
ritual_newID = ritual_mirrorShard.copy()
ritual_newID.insert(0, 'Days', range(1, 1+len(ritual_newID['Date'])))
ritual_newID = ritual_newID.reset_index()
ritual_newID = ritual_newID.drop(columns=['index'])

# %%
kalandra_newID.head(20)
# Out:
#     Days    League        Date           Get        Pay       Value Confidence
# 0      1  Kalandra  2022-08-20  Mirror Shard  Chaos Orb   550.00000        Low
# 1      2  Kalandra  2022-08-23  Mirror Shard  Chaos Orb   938.23530     Medium
# 2      3  Kalandra  2022-08-24  Mirror Shard  Chaos Orb   908.56842        Low
# 3      4  Kalandra  2022-08-25  Mirror Shard  Chaos Orb   929.60000        Low
# 4      5  Kalandra  2022-08-26  Mirror Shard  Chaos Orb  1000.00000        Low
# 5      6  Kalandra  2022-08-27  Mirror Shard  Chaos Orb  1250.00000        Low
# 6      7  Kalandra  2022-08-28  Mirror Shard  Chaos Orb  1250.00000        Low
# 7      8  Kalandra  2022-08-29  Mirror Shard  Chaos Orb  1140.00000        Low
# 8      9  Kalandra  2022-08-30  Mirror Shard  Chaos Orb  1500.00000        Low
# 9     10  Kalandra  2022-08-31  Mirror Shard  Chaos Orb  1419.47368        Low
# 10    11  Kalandra  2022-09-01  Mirror Shard  Chaos Orb  1410.00000        Low
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard', fontsize=15,fontweight='bold')
ax.plot(kalandra_newID['Days'],kalandra_newID['Value'], label = 'Kalandra')
ax.plot(sentinel_newID['Days'],sentinel_newID['Value'], label = 'Sentinel')
ax.plot(archnemesis_newID['Days'],archnemesis_newID['Value'], label = 'Archnemesis')
ax.plot(scourge_newID['Days'],scourge_newID['Value'], label = 'Scourge')
ax.plot(expedition_newID['Days'],expedition_newID['Value'], label = 'Expedition')
ax.plot(ultimatum_newID['Days'],ultimatum_newID['Value'], label = 'Ultimatum')
ax.plot(ritual_newID['Days'],ritual_newID['Value'], label = 'Ritual')
ax.legend()

fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\907269940.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
kalandra_mirrorPCT = kalandra_mirrorShard.copy()
kalandra_mirrorPCT.insert(0, 'Pct_change', kalandra_mirrorPCT['Value'].pct_change())
kalandra_mirrorPCT.insert(0, 'Days', range(1, 1+len(kalandra_mirrorPCT['Date'])))
# kalandra_mirrorPCT = kalandra_newID['Value'].pct_change()
kalandra_mirrorPCT.head(15)
# Out:
#        Days  Pct_change    League        Date           Get        Pay  \
# 12068     1         NaN  Kalandra  2022-08-20  Mirror Shard  Chaos Orb
# 12069     2   -0.880769  Kalandra  2022-08-22  Mirror Shard  Chaos Orb
# 12070     3   13.307325  Kalandra  2022-08-23  Mirror Shard  Chaos Orb
# 12071     4   -0.031620  Kalandra  2022-08-24  Mirror Shard  Chaos Orb
# 12072     5    0.023148  Kalandra  2022-08-25  Mirror Shard  Chaos Orb
# 12073     6    0.075731  Kalandra  2022-08-26  Mirror Shard  Chaos Orb
# 12074     7    0.250000  Kalandra  2022-08-27  Mirror Shard  Chaos Orb
# 12075     8    0.000000  Kalandra  2022-08-28  Mirror Shard  Chaos Orb
# 12076     9   -0.088000  Kalandra  2022-08-29  Mirror Shard  Chaos Orb
# 12077    10    0.315789  Kalandra  2022-08-30  Mirror Shard  Chaos Orb
# 12078    11   -0.053684  Kalandra  2022-08-31  Mirror Shard  Chaos Orb
# 12079    12   -0.006674  Kalandra  2022-09-01  Mirror Shard  Chaos Orb
# ...

# %%
sentinel_mirrorPCT = sentinel_mirrorShard.copy()
sentinel_mirrorPCT.insert(0, 'Pct_change', sentinel_mirrorPCT['Value'].pct_change())
sentinel_mirrorPCT.insert(0, 'Days', range(1, 1+len(sentinel_mirrorPCT['Date'])))
# kalandra_mirrorPCT = kalandra_newID['Value'].pct_change()
sentinel_mirrorPCT.head(15)
# Out:
#        Days  Pct_change    League        Date           Get        Pay  \
# 15666     1         NaN  Sentinel  2022-05-14  Mirror Shard  Chaos Orb
# 15667     2    0.070058  Sentinel  2022-05-15  Mirror Shard  Chaos Orb
# 15668     3    0.245583  Sentinel  2022-05-16  Mirror Shard  Chaos Orb
# 15669     4    0.074288  Sentinel  2022-05-17  Mirror Shard  Chaos Orb
# 15670     5   -0.055766  Sentinel  2022-05-18  Mirror Shard  Chaos Orb
# 15671     6    0.366849  Sentinel  2022-05-19  Mirror Shard  Chaos Orb
# 15672     7    0.137793  Sentinel  2022-05-20  Mirror Shard  Chaos Orb
# 15673     8    0.003448  Sentinel  2022-05-21  Mirror Shard  Chaos Orb
# 15674     9    0.037969  Sentinel  2022-05-22  Mirror Shard  Chaos Orb
# 15675    10    0.127022  Sentinel  2022-05-23  Mirror Shard  Chaos Orb
# 15676    11    0.182556  Sentinel  2022-05-24  Mirror Shard  Chaos Orb
# 15677    12   -0.007078  Sentinel  2022-05-25  Mirror Shard  Chaos Orb
# ...

# %%
archnemesis_mirrorPCT = archnemesis_mirrorShard.copy()
archnemesis_mirrorPCT.insert(0, 'Pct_change', archnemesis_mirrorPCT['Value'].pct_change())
archnemesis_mirrorPCT.insert(0, 'Days', range(1, 1+len(archnemesis_mirrorPCT['Date'])))
archnemesis_mirrorPCT.head(15)
# Out:
#       Days  Pct_change       League        Date           Get        Pay  \
# 6858     1         NaN  Archnemesis  2022-02-05  Mirror Shard  Chaos Orb
# 6859     2   -0.325831  Archnemesis  2022-02-06  Mirror Shard  Chaos Orb
# 6860     3    0.161775  Archnemesis  2022-02-07  Mirror Shard  Chaos Orb
# 6861     4   -0.081121  Archnemesis  2022-02-08  Mirror Shard  Chaos Orb
# 6862     5    0.041493  Archnemesis  2022-02-09  Mirror Shard  Chaos Orb
# 6863     6    0.318834  Archnemesis  2022-02-10  Mirror Shard  Chaos Orb
# 6864     7    0.093458  Archnemesis  2022-02-11  Mirror Shard  Chaos Orb
# 6865     8   -0.026263  Archnemesis  2022-02-12  Mirror Shard  Chaos Orb
# 6866     9   -0.041093  Archnemesis  2022-02-13  Mirror Shard  Chaos Orb
# 6867    10    0.347773  Archnemesis  2022-02-14  Mirror Shard  Chaos Orb
# 6868    11    0.206194  Archnemesis  2022-02-15  Mirror Shard  Chaos Orb
# 6869    12   -0.060372  Archnemesis  2022-02-16  Mirror Shard  Chaos Orb
# ...

# %%
scourge_mirrorPCT = scourge_mirrorShard.copy()
scourge_mirrorPCT.insert(0, 'Pct_change', scourge_mirrorPCT['Value'].pct_change())
scourge_mirrorPCT.insert(0, 'Days', range(1, 1+len(scourge_mirrorPCT['Date'])))
scourge_mirrorPCT.head(15)
# Out:
#        Days  Pct_change   League        Date           Get        Pay  \
# 19107     1         NaN  Scourge  2021-10-24  Mirror Shard  Chaos Orb
# 19108     2   -0.418037  Scourge  2021-10-25  Mirror Shard  Chaos Orb
# 19109     3   -0.164394  Scourge  2021-10-26  Mirror Shard  Chaos Orb
# 19110     4   -0.041571  Scourge  2021-10-27  Mirror Shard  Chaos Orb
# 19111     5    0.062019  Scourge  2021-10-28  Mirror Shard  Chaos Orb
# 19112     6    0.175726  Scourge  2021-10-29  Mirror Shard  Chaos Orb
# 19113     7    0.010417  Scourge  2021-10-30  Mirror Shard  Chaos Orb
# 19114     8    0.010309  Scourge  2021-10-31  Mirror Shard  Chaos Orb
# 19115     9    0.201233  Scourge  2021-11-01  Mirror Shard  Chaos Orb
# 19116    10    0.149069  Scourge  2021-11-02  Mirror Shard  Chaos Orb
# 19117    11    0.040658  Scourge  2021-11-03  Mirror Shard  Chaos Orb
# 19118    12    0.049180  Scourge  2021-11-04  Mirror Shard  Chaos Orb
# ...

# %%
expedition_mirrorPCT = expedition_mirrorShard.copy()
expedition_mirrorPCT.insert(0, 'Pct_change', expedition_mirrorPCT['Value'].pct_change())
expedition_mirrorPCT.insert(0, 'Days', range(1, 1+len(expedition_mirrorPCT['Date'])))
expedition_mirrorPCT.head(15)
# Out:
#        Days  Pct_change      League        Date           Get        Pay  \
# 18087     1         NaN  Expedition  2021-07-25  Mirror Shard  Chaos Orb
# 18088     2   -0.215775  Expedition  2021-07-26  Mirror Shard  Chaos Orb
# 18089     3   -0.041854  Expedition  2021-07-27  Mirror Shard  Chaos Orb
# 18090     4   -0.149816  Expedition  2021-07-28  Mirror Shard  Chaos Orb
# 18091     5   -0.144144  Expedition  2021-07-29  Mirror Shard  Chaos Orb
# 18092     6    0.444080  Expedition  2021-07-30  Mirror Shard  Chaos Orb
# 18093     7    0.089749  Expedition  2021-07-31  Mirror Shard  Chaos Orb
# 18094     8   -0.103851  Expedition  2021-08-01  Mirror Shard  Chaos Orb
# 18095     9    0.052441  Expedition  2021-08-02  Mirror Shard  Chaos Orb
# 18096    10    0.239917  Expedition  2021-08-03  Mirror Shard  Chaos Orb
# 18097    11    0.038519  Expedition  2021-08-04  Mirror Shard  Chaos Orb
# 18098    12    0.015039  Expedition  2021-08-05  Mirror Shard  Chaos Orb
# ...

# %%
ultimatum_mirrorPCT = ultimatum_mirrorShard.copy()
ultimatum_mirrorPCT.insert(0, 'Pct_change', ultimatum_mirrorPCT['Value'].pct_change())
ultimatum_mirrorPCT.insert(0, 'Days', range(1, 1+len(ultimatum_mirrorPCT['Date'])))
ultimatum_mirrorPCT.head(15)
# Out:
#       Days  Pct_change     League        Date           Get        Pay  \
# 6611     1         NaN  Ultimatum  2021-04-17  Mirror Shard  Chaos Orb
# 6612     2    2.128243  Ultimatum  2021-04-18  Mirror Shard  Chaos Orb
# 6613     3    0.104117  Ultimatum  2021-04-19  Mirror Shard  Chaos Orb
# 6614     4    0.004003  Ultimatum  2021-04-20  Mirror Shard  Chaos Orb
# 6615     5    0.123231  Ultimatum  2021-04-21  Mirror Shard  Chaos Orb
# 6616     6    0.145165  Ultimatum  2021-04-22  Mirror Shard  Chaos Orb
# 6617     7   -0.096844  Ultimatum  2021-04-23  Mirror Shard  Chaos Orb
# 6618     8    0.015152  Ultimatum  2021-04-24  Mirror Shard  Chaos Orb
# 6619     9    0.017843  Ultimatum  2021-04-25  Mirror Shard  Chaos Orb
# 6620    10    0.214984  Ultimatum  2021-04-26  Mirror Shard  Chaos Orb
# 6621    11    0.126950  Ultimatum  2021-04-27  Mirror Shard  Chaos Orb
# 6622    12   -0.048155  Ultimatum  2021-04-28  Mirror Shard  Chaos Orb
# ...

# %%
ritual_mirrorPCT = ritual_mirrorShard.copy()
ritual_mirrorPCT.insert(0, 'Pct_change', ritual_mirrorPCT['Value'].pct_change())
ritual_mirrorPCT.insert(0, 'Days', range(1, 1+len(ritual_mirrorPCT['Date'])))
ritual_mirrorPCT.head(15)
# Out:
#        Days  Pct_change  League        Date           Get        Pay  \
# 15367     1         NaN  Ritual  2021-01-16  Mirror Shard  Chaos Orb
# 15368     2   -0.416129  Ritual  2021-01-17  Mirror Shard  Chaos Orb
# 15369     3    0.012137  Ritual  2021-01-18  Mirror Shard  Chaos Orb
# 15370     4   -0.115705  Ritual  2021-01-19  Mirror Shard  Chaos Orb
# 15371     5    0.071705  Ritual  2021-01-20  Mirror Shard  Chaos Orb
# 15372     6   -0.066908  Ritual  2021-01-21  Mirror Shard  Chaos Orb
# 15373     7    0.012346  Ritual  2021-01-22  Mirror Shard  Chaos Orb
# 15374     8   -0.062500  Ritual  2021-01-23  Mirror Shard  Chaos Orb
# 15375     9   -0.078049  Ritual  2021-01-24  Mirror Shard  Chaos Orb
# 15376    10    0.128748  Ritual  2021-01-25  Mirror Shard  Chaos Orb
# 15377    11    0.138319  Ritual  2021-01-26  Mirror Shard  Chaos Orb
# 15378    12    0.000653  Ritual  2021-01-27  Mirror Shard  Chaos Orb
# 15379    13    0.012346  Ritual  2021-01-28  Mirror Shard  Chaos Orb
# ...

# %%
kalandra_mirrorPCT.loc[kalandra_mirrorPCT.Pct_change > 10, 'Pct_change'] = 0
kalandra_mirrorPCT.loc[kalandra_mirrorPCT.Pct_change < -0.5, 'Pct_change'] = 0
archnemesis_mirrorPCT.loc[archnemesis_mirrorPCT.Pct_change < -0.3, 'Pct_change'] = 0
scourge_mirrorPCT.loc[scourge_mirrorPCT.Pct_change < -0.3, 'Pct_change'] = 0
ultimatum_mirrorPCT.loc[ultimatum_mirrorPCT.Pct_change > 1, 'Pct_change'] = 0



# kalandra_mirrorPCT['Pct_change']

# %%
kalandra_mirrorPCT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 12068 to 12175
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Days        108 non-null    int64
#  1   Pct_change  107 non-null    float64
#  2   League      108 non-null    object
#  3   Date        108 non-null    object
#  4   Get         108 non-null    object
#  5   Pay         108 non-null    object
#  6   Value       108 non-null    float64
#  7   Confidence  108 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 7.6+ KB

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard in percentage for kalandra', fontsize=15,fontweight='bold')
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.plot(kalandra_mirrorPCT['Days'],kalandra_mirrorPCT['Pct_change'],label = 'Kalandra')
ax.plot(sentinel_mirrorPCT['Days'],sentinel_mirrorPCT['Pct_change'],label = 'Sentinel')
ax.plot(archnemesis_mirrorPCT['Days'],archnemesis_mirrorPCT['Pct_change'],label = 'Archnemesis')
ax.plot(scourge_mirrorPCT['Days'],scourge_mirrorPCT['Pct_change'],label = 'Scourge')
ax.plot(expedition_mirrorPCT['Days'],expedition_mirrorPCT['Pct_change'],label = 'Expedition')
ax.plot(ultimatum_mirrorPCT['Days'],ultimatum_mirrorPCT['Pct_change'],label = 'Ultimatum')
ax.plot(ritual_mirrorPCT['Days'],ritual_mirrorPCT['Pct_change'],label = 'Ritual')
ax.legend()


fig.show()
# Out:
# C:\Users\65978\AppData\Local\Temp\ipykernel_21952\337350710.py:18: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# kalandra_Ref1stDay = kalandra_mirrorShard['Value'].copy()
# kalandra_Ref1stDay['Value'].apply(lambda x: x.div(x.iloc[0]).subtract(1.0).mul(100.0))
# Error : AttributeError: 'float' object has no attribute 'div'
# Because Float does not contain div, But the Dataframe does.
# kalandra_Ref1stDay.groupby('League')['Value']
# df = kalandra_Ref1stDay['Value'].expanding().apply(lambda x: x.div(x.iloc[0]).subtract(1.0).mul(100.0))
kalandra_Ref1stDay = kalandra_mirrorShard.copy()
kalandra_Ref1stDay = kalandra_Ref1stDay[kalandra_Ref1stDay.Value > 66]

sentinel_Ref1stDay = sentinel_mirrorShard.copy()
archnemesis_Ref1stDay = archnemesis_mirrorShard.copy()
scourge_Ref1stDay = scourge_mirrorShard.copy()
expedition_Ref1stDay = expedition_mirrorShard.copy()
ultimatum_Ref1stDay = ultimatum_mirrorShard.copy()
ritual_Ref1stDay = ritual_mirrorShard.copy()

# %%
def get_variation(values: pd.Series) -> np.float64:
    base = values.iloc[0]  # first element in window iteration
    current = values.iloc[-1]  # last element in window iteration

    return (current - base) / base if base else 0  # avoid ZeroDivisionError

# variations = archnemesis_Ref1stDay['Value'].expanding().apply(get_variation)
kalandra_Ref1stDay.insert(0, 'Days', range(1, 1+len(kalandra_Ref1stDay['Date'])))
kalandra_Ref1stDay.insert(4, 'Pct_change_RefDay_1', kalandra_Ref1stDay['Value'].expanding().apply(get_variation))
# kalandra_Ref1stDay = kalandra_Ref1stDay.assign(change=variations.droplevel(0))
sentinel_Ref1stDay.insert(0, 'Days', range(1, 1+len(sentinel_Ref1stDay['Date'])))
sentinel_Ref1stDay.insert(4, 'Pct_change_RefDay_1', sentinel_Ref1stDay['Value'].expanding().apply(get_variation))
archnemesis_Ref1stDay.insert(0, 'Days', range(1, 1+len(archnemesis_Ref1stDay['Date'])))
archnemesis_Ref1stDay.insert(4, 'Pct_change_RefDay_1', archnemesis_Ref1stDay['Value'].expanding().apply(get_variation))
scourge_Ref1stDay.insert(0, 'Days', range(1, 1+len(scourge_Ref1stDay['Date'])))
scourge_Ref1stDay.insert(4, 'Pct_change_RefDay_1', scourge_Ref1stDay['Value'].expanding().apply(get_variation))

expedition_Ref1stDay.insert(0, 'Days', range(1, 1+len(expedition_Ref1stDay['Date'])))
expedition_Ref1stDay.insert(4, 'Pct_change_RefDay_1', expedition_Ref1stDay['Value'].expanding().apply(get_variation))
ultimatum_Ref1stDay.insert(0, 'Days', range(1, 1+len(ultimatum_Ref1stDay['Date'])))
ultimatum_Ref1stDay.insert(4, 'Pct_change_RefDay_1', ultimatum_Ref1stDay['Value'].expanding().apply(get_variation))
ritual_Ref1stDay.insert(0, 'Days', range(1, 1+len(ritual_Ref1stDay['Date'])))
ritual_Ref1stDay.insert(4, 'Pct_change_RefDay_1', ritual_Ref1stDay['Value'].expanding().apply(get_variation))

# %%
# variations.head(20)
archnemesis_Ref1stDay.head(20)
# Out:
#       Days       League        Date           Get  Pct_change_RefDay_1  \
# 6858     1  Archnemesis  2022-02-05  Mirror Shard             0.000000
# 6859     2  Archnemesis  2022-02-06  Mirror Shard            -0.325831
# 6860     3  Archnemesis  2022-02-07  Mirror Shard            -0.216768
# 6861     4  Archnemesis  2022-02-08  Mirror Shard            -0.280305
# 6862     5  Archnemesis  2022-02-09  Mirror Shard            -0.250442
# 6863     6  Archnemesis  2022-02-10  Mirror Shard            -0.011458
# 6864     7  Archnemesis  2022-02-11  Mirror Shard             0.080929
# 6865     8  Archnemesis  2022-02-12  Mirror Shard             0.052540
# 6866     9  Archnemesis  2022-02-13  Mirror Shard             0.009289
# 6867    10  Archnemesis  2022-02-14  Mirror Shard             0.360292
# 6868    11  Archnemesis  2022-02-15  Mirror Shard             0.640775
# 6869    12  Archnemesis  2022-02-16  Mirror Shard             0.541719
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Chaos Price for Mirror Shard in percentage for kalandra', fontsize=15,fontweight='bold')
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))


ax.plot(kalandra_Ref1stDay['Days'],kalandra_Ref1stDay['Pct_change_RefDay_1'],label = 'kalandra')
ax.plot(sentinel_Ref1stDay['Days'],sentinel_Ref1stDay['Pct_change_RefDay_1'],label = 'sentinel')
ax.plot(archnemesis_Ref1stDay['Days'],archnemesis_Ref1stDay['Pct_change_RefDay_1'],label = 'Archnemesis')
ax.plot(scourge_Ref1stDay['Days'],scourge_Ref1stDay['Pct_change_RefDay_1'],label = 'scourge')

ax.plot(expedition_Ref1stDay['Days'],expedition_Ref1stDay['Pct_change_RefDay_1'],label = 'expedition')
ax.plot(ultimatum_Ref1stDay['Days'],ultimatum_Ref1stDay['Pct_change_RefDay_1'],label = 'ultimatum')
ax.plot(ritual_Ref1stDay['Days'],ritual_Ref1stDay['Pct_change_RefDay_1'],label = 'ritual')
ax.legend()

# %%
glued_kalandra = kalandra_Ref1stDay.copy()
glued_sentinel = sentinel_Ref1stDay.copy()
glued_sentinel = glued_sentinel.reset_index()
glued_archnemesis = archnemesis_Ref1stDay.copy()
glued_archnemesis = glued_archnemesis.reset_index()
glued_scourge = scourge_Ref1stDay.copy()
glued_scourge = glued_scourge.reset_index()
glued_expedition = expedition_Ref1stDay.copy()
glued_expedition = glued_expedition.reset_index()

glued = pd.concat([glued_scourge['Days'],glued_kalandra['Pct_change_RefDay_1'],
                   glued_sentinel['Pct_change_RefDay_1'], glued_archnemesis['Pct_change_RefDay_1'],
                  glued_scourge['Pct_change_RefDay_1'],glued_expedition['Pct_change_RefDay_1']], axis=1)
# glued
df = glued.groupby(level=0, axis=1).mean()
fig, ax = plt.subplots(figsize=(20,10))
plt.title('Average League Chaos Price for Mirror Shard in percentage', fontsize=15,fontweight='bold')
# plt.ylim(-1,25)
ax.xaxis.set_minor_locator(MultipleLocator(1))
ax.xaxis.set_major_locator(MultipleLocator(5))
ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
ax.yaxis.set_minor_locator(AutoMinorLocator(5))

ax.plot(df['Days'],df['Pct_change_RefDay_1'],label = 'Combined')
ax.legend()
